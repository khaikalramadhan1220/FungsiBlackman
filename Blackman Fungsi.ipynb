# %%
import numpy as np
import matplotlib.pyplot as plt
np.blackman(12)
# Out:
# array([-1.38777878e-17,  3.26064346e-02,  1.59903635e-01,  4.14397981e-01,
#         7.36045180e-01,  9.67046769e-01,  9.67046769e-01,  7.36045180e-01,
#         4.14397981e-01,  1.59903635e-01,  3.26064346e-02, -1.38777878e-17])

# %%
from numpy.fft import fft, fftshift
window = np.blackman(51)
plt.plot(window)

plt.title("window Blackman")

plt.ylabel("Amplitudo")

plt.xlabel("Sampel")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1167d6256c52> in <module>
#       1 from numpy.fft import fft, fftshift
# ----> 2 window = np.blackman(51)
#       3 plt.plot(window)
#       4
#       5 plt.title("window Blackman")
#
# NameError: name 'np' is not defined

# %%
plt.plot(window)
plt.figure()

A = fft(window, 2048) / 25.5
mag = np.abs(fftshift(A))
freq = np.linspace(-0.5, 0.5, len(A))
with np.errstate(divide='ignore', invalid='ignore'):
    response = 20 * np.log10(mag)

response = np.clip(response, -100, 100)
plt.plot(freq, response)

plt.title("Frequency response of Blackman window")

plt.ylabel("Magnitude [dB]")

plt.xlabel(" Frekuensi Normalisasi [cycles per sample]")

_ = plt.axis('tight')
plt.show()
